# %% [markdown]
# # Miniproject 1: Image Classification
#
# ## Introduction
#
# ### Description
#
# One of the deepest traditions in learning about deep learning is to first [tackle the exciting problem of MNIST classification](http://deeplearning.net/tutorial/logreg.html). [The MNIST database](https://en.wikipedia.org/wiki/MNIST_database) (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that was [recently extended](https://arxiv.org/abs/1702.05373). We break with this tradition (just a little bit) and tackle first the related problem of classifying cropped, downsampled and grayscaled images of house numbers in the [The Street View House Numbers (SVHN) Dataset](http://ufldl.stanford.edu/housenumbers/).
#
#
# ### Prerequisites
#
# - You should have a running installation of [tensorflow](https://www.tensorflow.org/install/) and [keras](https://keras.io/).
# - You should know the concepts "multilayer perceptron", "stochastic gradient descent with minibatches", "training and validation data", "overfitting" and "early stopping".
#
# ### What you will learn
#
# - You will learn how to define feedforward neural networks in keras and fit them to data.
# - You will be guided through a prototyping procedure for the application of deep learning to a specific domain.
# - You will get in contact with concepts discussed later in the lecture, like "regularization", "batch normalization" and "convolutional networks".
# - You will gain some experience on the influence of network architecture, optimizer and regularization choices on the goodness of fit.
# - You will learn to be more patient :) Some fits may take your computer quite a bit of time; run them over night.
#
# ### Evaluation criteria
#
# The evaluation is (mostly) based on the figures you submit and your answer sentences.
# We will only do random tests of your code and not re-run the full notebook.
#
# ### Your names
#
# Before you start, please enter your full name(s) in the field below; they are used to load the data. The variable student2 may remain empty, if you work alone.

# %%
student1 = "Valentin Kindschi"
student2 = "Antoine Hoffmann"

# %% [markdown]
# ## Some helper functions
#
# For your convenience we provide here some functions to preprocess the data and plot the results later. Simply run the following cells with `Shift-Enter`.
#
# ### Dependencies and constants

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import scipy.io

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.optimizers import SGD, Adam

from scipy.optimize import fsolve
import json

# you may experiment with different subsets, 
# but make sure in the submission 
# it is generated with the correct random seed for all exercises.
np.random.seed(234445+236838)
subset_of_classes = np.random.choice(range(10), 5, replace = False)

# %% [markdown]
# ### Plotting

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
def plot_some_samples(x, y = [], yhat = [], select_from = [], 
                      ncols = 6, nrows = 4, xdim = 16, ydim = 16,
                      label_mapping = range(10)):
    """plot some input vectors as grayscale images (optionally together with their assigned or predicted labels).
    
    x is an NxD - dimensional array, where D is the length of an input vector and N is the number of samples.
    Out of the N samples, ncols x nrows indices are randomly selected from the list select_from (if it is empty, select_from becomes range(N)).
    
    Keyword arguments:
    y             -- corresponding labels to plot in green below each image.
    yhat          -- corresponding predicted labels to plot in red below each image.
    select_from   -- list of indices from which to select the images.
    ncols, nrows  -- number of columns and rows to plot.
    xdim, ydim    -- number of pixels of the images in x- and y-direction.
    label_mapping -- map labels to digits.
    
    """
    fig, ax = plt.subplots(nrows, ncols)
    if len(select_from) == 0:
        select_from = range(x.shape[0])
    indices = np.random.choice(select_from, size = min(ncols * nrows, len(select_from)), replace = False)
    for i, ind in enumerate(indices):
        thisax = ax[i//ncols,i%ncols]
        thisax.matshow(x[ind].reshape(xdim, ydim), cmap='gray')
        thisax.set_axis_off()
        if len(y) != 0:
            j = y[ind] if type(y[ind]) != np.ndarray else y[ind].argmax()
            thisax.text(0, 0, (label_mapping[j]+1)%10, color='green', 
                                                       verticalalignment='top',
                                                       transform=thisax.transAxes)
        if len(yhat) != 0:
            k = yhat[ind] if type(yhat[ind]) != np.ndarray else yhat[ind].argmax()
            thisax.text(1, 0, (label_mapping[k]+1)%10, color='red',
                                             verticalalignment='top',
                                             horizontalalignment='right',
                                             transform=thisax.transAxes)
    return fig

def prepare_standardplot(title, xlabel):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle(title)
    ax1.set_ylabel('categorical cross entropy')
    ax1.set_xlabel(xlabel)
    ax1.set_yscale('log')
    ax2.set_ylabel('accuracy [% correct]')
    ax2.set_xlabel(xlabel)
    return fig, ax1, ax2

def finalize_standardplot(fig, ax1, ax2):
    ax1handles, ax1labels = ax1.get_legend_handles_labels()
    if len(ax1labels) > 0:
        ax1.legend(ax1handles, ax1labels)
    ax2handles, ax2labels = ax2.get_legend_handles_labels()
    if len(ax2labels) > 0:
        ax2.legend(ax2handles, ax2labels)
    fig.tight_layout()
    plt.subplots_adjust(top=0.9)

def plot_history(history, title):
    fig, ax1, ax2 = prepare_standardplot(title, 'epoch')
    ax1.plot(history.history['loss'], label = "training")
    ax1.plot(history.history['val_loss'], label = "validation")
    ax2.plot(history.history['acc'], label = "training")
    ax2.plot(history.history['val_acc'], label = "validation")
    finalize_standardplot(fig, ax1, ax2)
    return fig

# %% [markdown]
# ### Loading and preprocessing the data
#
# The data consists of RGB color images with 32x32 pixels, loaded into an array of dimension 32x32x3x(number of images). We convert them to grayscale (using [this method](https://en.wikipedia.org/wiki/SRGB#The_reverse_transformation)) and we downsample them to images of 16x16 pixels by averaging over patches of 2x2 pixels.
#
# With these preprocessing steps we obviously remove some information that could be helpful in classifying the images. But, since the processed data is much lower dimensional, the fitting procedures converge faster. This is an advantage in situations like here (or generally when prototyping), were we want to try many different things without having to wait too long for computations to finish. After having gained some experience, one may want to go back to work on the 32x32 RGB images.

# %%
# convert RGB images x to grayscale using the formula for Y_linear in https://en.wikipedia.org/wiki/Grayscale#Colorimetric_(perceptual_luminance-preserving)_conversion_to_grayscale
def grayscale(x):
    x = x.astype('float32')/255
    x = np.piecewise(x, [x <= 0.04045, x > 0.04045], 
                        [lambda x: x/12.92, lambda x: ((x + .055)/1.055)**2.4])
    return .2126 * x[:,:,0,:] + .7152 * x[:,:,1,:]  + .07152 * x[:,:,2,:]

def downsample(x):
    return sum([x[i::2,j::2,:] for i in range(2) for j in range(2)])/4

def preprocess(data):
    gray = grayscale(data['X'])
    downsampled = downsample(gray)
    return (downsampled.reshape(16*16, gray.shape[2]).transpose(),
            data['y'].flatten() - 1)


data_train = scipy.io.loadmat('housenumbers/train_32x32.mat')
data_test = scipy.io.loadmat('housenumbers/test_32x32.mat')

x_train_all, y_train_all = preprocess(data_train)
x_test_all, y_test_all = preprocess(data_test)

# %% [markdown]
# ### Selecting a subset of classes
#
# We furter reduce the size of the dataset (and thus reduce computation time) by selecting only the 5 (out of 10 digits) in subset_of_classes.

# %%
def extract_classes(x, y, classes):
    indices = []
    labels = []
    count = 0
    for c in classes:
        tmp = np.where(y == c)[0]
        indices.extend(tmp)
        labels.extend(np.ones(len(tmp), dtype='uint8') * count)
        count += 1
    return x[indices], labels

x_train, y_train = extract_classes(x_train_all, y_train_all, subset_of_classes)
x_test, y_test = extract_classes(x_test_all, y_test_all, subset_of_classes)

# %% [markdown]
# Let us plot some examples now. The green digit at the bottom left of each image indicates the corresponding label in y_test.
# For further usage of the function plot_some_samples, please have a look at its definition in the plotting section.

# %%
plot_some_samples(x_test, y_test, label_mapping = subset_of_classes);

# %% [markdown]
# To prepare for fitting we transform the labels to one hot coding, i.e. for 5 classes, label 2 becomes the vector [0, 0, 1, 0, 0] (python uses 0-indexing).

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %% [markdown]
# ## Exercise 1: No hidden layer
#
# ### Description
#
# Define and fit a model without a hidden layer.
#
# 1. Use the softmax activation for the output layer.
# 2. Use the categorical_crossentropy loss.
# 3. Add the accuracy metric to the metrics.
# 4. Choose stochastic gradient descent for the optimizer.
# 5. Choose a minibatch size of 128.
# 6. Fit for as many epochs as needed to see no further decrease in the validation loss.
# 7. Plot the output of the fitting procedure (a history object) using the function plot_history defined above.
# 8. Determine the indices of all test images that are misclassified by the fitted model and plot some of them using the function
#    `plot_some_samples(x_test, y_test, yhat_test, error_indices, label_mapping = subset_of_classes)`
#
#
# Hints:
# * Read the keras docs, in particular [Getting started with the Keras Sequential model](https://keras.io/getting-started/sequential-model-guide/).
# * Have a look at the keras [examples](https://github.com/keras-team/keras/tree/master/examples), e.g. [mnist_mlp](https://github.com/keras-team/keras/blob/master/examples/mnist_mlp.py).

# %% [markdown]
# ### Solution

# %%
#Optimization of a monolayer neural network with SGD and lr=0.1
batch_size = 128
num_classes = 5
epochs = 500

model = Sequential()
model.add(Dense(num_classes, activation='softmax', input_dim=x_train.shape[1]))

sgd = keras.optimizers.SGD(lr=0.1, momentum=0.0, decay=0.0, nesterov=False)

model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (x_test, y_test))

yhat_test = model.predict(x_test, 
                          batch_size=batch_size,
                          verbose=0)

score = model.evaluate(x_test, y_test, verbose = 0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
model.summary()
# Out:
# Train on 36724 samples, validate on 13074 samples
# Epoch 1/500
# 36724/36724 [==============================] - 1s 27us/step - loss: 1.5234 - acc: 0.3789 - val_loss: 1.5042 - val_acc: 0.3977
# Epoch 2/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.5031 - acc: 0.3824 - val_loss: 1.4963 - val_acc: 0.3968
# Epoch 3/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4947 - acc: 0.3880 - val_loss: 1.4966 - val_acc: 0.4103
# Epoch 4/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4884 - acc: 0.3919 - val_loss: 1.4940 - val_acc: 0.4036
# Epoch 5/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4843 - acc: 0.3949 - val_loss: 1.4917 - val_acc: 0.4126
# Epoch 6/500
# 36724/36724 [==============================] - 1s 19us/step - loss: 1.4804 - acc: 0.3991 - val_loss: 1.4927 - val_acc: 0.4197
# Epoch 7/500
# 36724/36724 [==============================] - 1s 20us/step - loss: 1.4779 - acc: 0.4023 - val_loss: 1.4958 - val_acc: 0.4148
# Epoch 8/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4754 - acc: 0.4042 - val_loss: 1.4914 - val_acc: 0.4190
# Epoch 9/500
# 36724/36724 [==============================] - 1s 20us/step - loss: 1.4736 - acc: 0.4071 - val_loss: 1.4949 - val_acc: 0.4304
# Epoch 10/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4728 - acc: 0.4092 - val_loss: 1.4944 - val_acc: 0.4216
# Epoch 11/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.
500
# 36724/36724 [==============================] - 1s 22us/step - loss: 1.4428 - acc: 0.4411 - val_loss: 1.5172 - val_acc: 0.4387
# Epoch 494/500
# 36724/36724 [==============================] - 1s 21us/step - loss: 1.4429 - acc: 0.4421 - val_loss: 1.5165 - val_acc: 0.4464
# Epoch 495/500
# 36724/36724 [==============================] - 1s 23us/step - loss: 1.4432 - acc: 0.4421 - val_loss: 1.5207 - val_acc: 0.4432
# Epoch 496/500
# 36724/36724 [==============================] - 1s 22us/step - loss: 1.4428 - acc: 0.4424 - val_loss: 1.5215 - val_acc: 0.4423
# Epoch 497/500
# 36724/36724 [==============================] - 1s 20us/step - loss: 1.4432 - acc: 0.4416 - val_loss: 1.5202 - val_acc: 0.4445
# Epoch 498/500
# 36724/36724 [==============================] - 1s 23us/step - loss: 1.4433 - acc: 0.4414 - val_loss: 1.5140 - val_acc: 0.4429
# Epoch 499/500
# 36724/36724 [==============================] - 1s 22us/step - loss: 1.4430 - acc: 0.4414 - val_loss: 1.5137 - val_acc: 0.4442
# Epoch 500/500
# 36724/36724 [==============================] - 1s 22us/step - loss: 1.4431 - acc: 0.4418 - val_loss: 1.5148 - val_acc: 0.4421
# Test loss: 1.51481338617
# Test accuracy: 0.442098822091
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 1,285
# Trainable params: 1,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_history(history, 'SGD, No hidden layer');

# %%
nb_pattern = y_test.shape[0]
#Construction of a list containing the indices of network's wrong answers 
error_indices = []
#for i in range(int(y_test.size/y_test[1].size)): #y_test.size/y_test[1].size c'est peut-être pas très élégant...
for i in range(0,nb_pattern):
    answer_nn = 0
    answer = 0
    for j in range(0, 4):
        if(y_test[i][answer] < y_test[i][j]): # Looking for the maximal value to get the answer index
            answer = j   
        if(yhat_test[i][answer_nn] < yhat_test[i][j]):
            answer_nn = j
            
    if(answer_nn!=answer): # Comparing the answer of y and yhat, adding the pattern index if not correct
        error_indices.append(i)
        
print("Number of pattern : ",nb_pattern)
print("Size of error_indices : ", len(error_indices))
print("Error in % : ", len(error_indices)/nb_pattern)
plot_some_samples(x_test, y_test, yhat_test, error_indices, label_mapping = subset_of_classes);
# Out:
# Number of pattern :  13074
# Size of error_indices :  7410
# Error in % :  0.5667737494263424

# %%
#error_indices = [x for x in y_te
#answer = np.zeros_like(yhat_test) #create a matrix of zeros with the same shape as yhat_test
#answer[np.arange(len(yhat_test)),yhat_test.argmax(1)]=1 #set to 1 the max of each row

#error_indices = np.argwhere(np.sum(np.equal(answer,y_test),axis=1)==5) #not working yet
#plot_some_samples(x_test, y_test, yhat_test, error_indices, label_mapping = subset_of_classes)

# %% [markdown]
# ## Exercise 2: One hidden layer, different optizimizers
# ### Description
#
# Train a network with one hidden layer and compare different optimizers.
#
# 1. Use one hidden layer with 64 units and the 'relu' activation. Use the [summary method](https://keras.io/models/about-keras-models/) to inspect your model.
# 2. Fit the model for 50 epochs with different learning rates of stochastic gradient descent and answer the question below.
# 3. Replace the stochastic gradient descent optimizer with the [Adam optimizer](https://keras.io/optimizers/#adam).
# 4. Plot the learning curves of SGD with a reasonable learning rate together with the learning curves of Adam in the same figure. Take care of a reasonable labeling of the curves in the plot.

# %% [markdown]
# ### Solution

# %%
#Ex 2. Parameters initialization
batch_size = 128
num_classes = 5
epochs = 50
hidden_neurons = 64

# %% [markdown]
# SGD Optimizer:

# %%
#Optimization of a neural network with one hidden layer and SGD. Tunable learning rate.
def SGD_learning_rate(lr,SUM=False):
    
    model = Sequential()
    model.add(Dense(hidden_neurons, activation='relu', input_dim=x_train.shape[1]))
    model.add(Dense(num_classes, activation='softmax'))

    sgd = keras.optimizers.SGD(lr=lr, momentum=0.0, decay=0.0, nesterov=False)

    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                            batch_size = batch_size,
                            epochs = epochs,
                            verbose = 0,
                            validation_data = (x_test, y_test))
    if (SUM): model.summary()
    return history

# %%
#test
SGD_learning_rate(0.1,SUM=True);
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_32 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Analyse impact of learning rate on SGD Optimizer:

# %%
#different learning rates tested
lr = [0.001, 0.01, 0.1, 1.0, 10.0]

history_lr = {}
for i in lr:
    history_lr[i] = SGD_learning_rate(i,SUM=False).history

# %%
title1 = 'Comparison of training loss/acc for different learning rates'
#title2 = 'Comparison of validation loss/acc for different learning rates'
fig, ax1, ax2 = prepare_standardplot(title1, 'epoch')
#fig, ax3, ax4 = prepare_standardplot(title2, 'epoch')

for i in lr:
    ax1.plot(history_lr[i]['loss'], label = "SGD lr={}".format(str(i)))
    ax2.plot(history_lr[i]['acc'], label = "SGD lr={}".format(str(i)))
    #ax3.plot(history_lr[i]['val_loss'], label = "SGD lr={}".format(str(i)))
    #ax4.plot(history_lr[i]['val_acc'], label = "SGD lr={}".format(str(i)))

finalize_standardplot(fig, ax1, ax2)
#finalize_standardplot(fig, ax3, ax4)

# %% [markdown]
# **Question**: What happens if the learning rate of SGD is A) very large B) very small? Please answer A) and B) with one full sentence (double click this markdown cell to edit).
#
# **Answer**:
#
# A) With very large learning rate (tested with lr=10), the weights are changed too brutally which induces strong oscillations and unprecise convergence.
#
# B) With very small learning rate (tested with lr=0.001), the convergence is smooth but very slow because of the smaller changes in weights between the epochs.

# %% [markdown]
# **Generic Function using Adam Optimizer: (used in next exercises too)**

# %%
#Run adam optimizer on a Neural Network with tunable parameters
def adam_optimizer(**kwargs):
    
    #defualt parameters:
    K_hidden   = 0      if not 'K_hidden'   in kwargs.keys() else kwargs['K_hidden']
    N_hidden   = 64     if not 'N_hidden'   in kwargs.keys() else kwargs['N_hidden']
    batch_size = 128    if not 'batch_size' in kwargs.keys() else kwargs['batch_size']
    num_class  = 5      if not 'num_class'  in kwargs.keys() else kwargs['num_class']
    ES_bool    = False  if not 'ES_bool'    in kwargs.keys() else kwargs['ES_bool']
    epochs     = 100    if not 'epochs'     in kwargs.keys() else kwargs['epochs']
    verbose    = 0      if not 'verbose'    in kwargs.keys() else kwargs['verbose'] # 0 = silent, 1= progress bar, 2 = one line per epoch.
    SUMMARY    = False  if not 'SUMMARY'    in kwargs.keys() else kwargs['SUMMARY']
        
    #initialize callbacks
    callbacks = [keras.callbacks.TerminateOnNaN()]
    if ES_bool:
        callbacks.append(keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='min'))
    
    #define model
    model = Sequential()
    if (K_hidden == 0):
        model.add(Dense(num_class, activation='softmax',input_dim=x_train.shape[1]))
    #hidden layers
    else:        
        for k in range(0,K_hidden):
            if (k == 0): model.add(Dense(N_hidden, activation='relu', input_dim=x_train.shape[1]))
            else: model.add(Dense(N_hidden, activation='relu', input_dim=N_hidden))
        model.add(Dense(num_class, activation='softmax'))
    
    #use adam optimizer
    adamopt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    
    model.compile(optimizer= adamopt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    history = model.fit(x_train, y_train,
                        batch_size = batch_size,
                        epochs = epochs,
                        verbose = verbose,
                        callbacks = callbacks,
                        validation_data = (x_test, y_test))
    
    #output summary
    if (SUMMARY): 
        model.summary()
    
    return history

# %% [markdown]
# Run Adam and SGD Optimizers:

# %%
history_sgd = SGD_learning_rate(0.1).history
history_adam = adam_optimizer(K_hidden=1,epochs=50,SUMMARY=True).history
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_26 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 16,773
# Trainable params: 16,773
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Comparison between SGD and Adam:

# %%
fig1, ax1, ax2 = prepare_standardplot('Comparison between Learning with SGD or Adam', 'epoch')
ax1.plot(history_sgd['loss'], label = "SGD (lr=0.001)")
ax1.plot(history_adam['loss'], label = "Adam")
ax2.plot(history_sgd['acc'], label = "SGD (lr=0.001)")
ax2.plot(history_adam['acc'], label = "Adam")
finalize_standardplot(fig, ax1, ax2)

# %% [markdown]
# ## Exercise 3: Overfitting and early stopping with Adam
#
# ### Description
#
# Run the above simulation with Adam for sufficiently many epochs (be patient!) until you see clear overfitting.
#
# 1. Plot the learning curves of a fit with Adam and sufficiently many epochs and answer the questions below.
#
# A simple, but effective mean to avoid overfitting is early stopping, i.e. a fit is not run until convergence but stopped as soon as the validation error starts to increase. We will use early stopping in all subsequent exercises.
#
# ### Solution

# %%
history_adam = adam_optimizer(N_hidden=64, K_hidden=1, ES_bool=False, epochs=1000, verbose=1)
plot_history(history_adam, "History adam")

# %% [markdown]
# **Question 1**: At which epoch (approximately) does the model start to overfit? Please answer with one full sentence.
#
# **Answer**:
#
# **Question 2**: Explain the qualitative difference between the loss curves and the accuracy curves with respect to signs of overfitting. Please answer with at most 3 full sentences.
#
# **Answer**:

# %% [markdown]
# ## Exercise 4: Model performance as a function of number of hidden neurons
#
# ### Description
#
# Investigate how the best validation loss and accuracy depends on the number of hidden neurons in a single layer.
#
# 1. Fit a reasonable number of models with different hidden layer size (between 10 and 1000 hidden neurons) for a fixed number of epochs well beyond the point of overfitting.
# 2. Collect some statistics by fitting the same models as in 1. for multiple initial conditions. Hints: 1. If you don't reset the random seed, you get different initial conditions each time you create a new model. 2. Let your computer work while you are asleep.
# 3. Plot summary statistics of the final validation loss and accuracy versus the number of hidden neurons. Hint: [boxplots](https://matplotlib.org/examples/pylab_examples/boxplot_demo.html) (also [here](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.boxplot.html?highlight=boxplot#matplotlib.axes.Axes.boxplot)) are useful. You may also want to use the matplotlib method set_xticklabels.
# 4. Plot summary statistics of the loss and accuracy for early stopping versus the number of hidden neurons.
#
# ### Solution

# %%
#test
history_adam_10 = adam_optimizer(N_hidden=10, K_hidden=1, ES_bool=True, epochs=100, verbose=0)
plot_history(history_adam_10, "History adam 10 hidden units");

# %% [markdown]
# Try first for 100 different number of hidden neurons between 10 and 1000:

# %%
#THIS BLOCK TAKES A FEW HOURS TO RUN
history_list4 = {}
for i in range(10,1001,10): #takes approx. 4-5h
    history_tmp = adam_optimizer(N_hidden=i, K_hidden=1, ES_bool=True, epochs=1000, verbose=0)
    history_list4[i] = history_tmp.history
        
#save statistics in json
with open('SavedData/ex4_results.txt', 'w') as outfile:
    json.dump(history_list4, outfile)
# Out:
# Epoch 00050: early stopping
# Test loss: 0.769558414309
# Test accuracy: 0.778797613575
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 10)                2570
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 55
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00059: early stopping
# Test loss: 0.613735055493
# Test accuracy: 0.830503288952
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 20)                5140
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 5,245
# Trainable params: 5,245
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00063: early stopping
# Test loss: 0.563842914731
# Test accuracy: 0.849472234998
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 30)                7710
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 155
# =================================================================
# Total params: 7,865
# Trainable params: 7,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00048: early stopping
# Test loss: 0.528427998571
# Test accuracy: 0.854367446859
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 40)                10280
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 205
# =================================================================
# Total params: 10,485
# Trainable params: 10,485
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00048: early stopping
# Test loss: 0.512298647656
# Test accuracy: 0.864081382879
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 50)                12850
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00052: early stopping
# Test loss: 0.480666025436
# Test accuracy: 0.872495028282
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 60)                15420
# _________________________________________________________________
# dense_15 (Dense)             (None, 5)                 305
# =================================================================
# Total params: 15,725
# Trainable params: 15,725
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00056: early stopping
# Test loss: 0.477761445524
# Test accuracy: 0.872418540597
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 70)                17990
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 355
# =================================================================
# Total params: 18,345
# Trainable params: 18,345
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00034: early stopping
# Test loss: 0.500236450468
# Test accuracy: 0.862628116891
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 80)                20560
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 405
# =================================================================
# Total params: 20,965
# Trainable params: 20,965
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00048: early stopping
# Test loss: 0.467855764809
# Test accuracy: 0.876242924916
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 90)                23130
# _________________________________________________________________
# dense_21 (Dense)             (None, 5)                 455
# =================================================================
# Total params: 23,585
# Trainable params: 23,585
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.498588996258
# Test accuracy: 0.862934067597
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_23 (Dense)             (None, 5)                 505
# =================================================================
# Total params: 26,205
# Trainable params: 26,205
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.487812585599
# Test accuracy: 0.868135230255
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 110)               28270
# _________________________________________________________________
# dense_25 (Dense)             (None, 5)                 555
# =================================================================
# Total params: 28,825
# Trainable params: 28,825
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.475043468625
# Test accuracy: 0.87050634846
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 120)               30840
# _________________________________________________________________
# dense_27 (Dense)             (None, 5)                 605
# =================================================================
# Total params: 31,445
# Trainable params: 31,445
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00033: early stopping
# Test loss: 0.455422545106
# Test accuracy: 0.876395900242
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 130)               33410
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 655
# =================================================================
# Total params: 34,065
# Trainable params: 34,065
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.468837850695
# Test accuracy: 0.87846106775
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 140)               35980
# _________________________________________________________________
# dense_31 (Dense)             (None, 5)                 705
# =================================================================
# Total params: 36,685
# Trainable params: 36,685
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00038: early stopping
# Test loss: 0.470091310867
# Test accuracy: 0.87517209732
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_32 (Dense)             (None, 150)               38550
# _________________________________________________________________
# dense_33 (Dense)             (None, 5)                 755
# =================================================================
# Total params: 39,305
# Trainable params: 39,305
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00037: early stopping
# Test loss: 0.464850552894
# Test accuracy: 0.877007801753
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 160)               41120
# _________________________________________________________________
# dense_35 (Dense)             (None, 5)                 805
# =================================================================
# Total params: 41,925
# Trainable params: 41,925
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00038: early stopping
# Test loss: 0.481147654226
# Test accuracy: 0.8760899495
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 170)               43690
# _________________________________________________________________
# dense_37 (Dense)             (None, 5)                 855
# =================================================================
# Total params: 44,545
# Trainable params: 44,545
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.472427303517
# Test accuracy: 0.87999082145
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_38 (Dense)             (None, 180)               46260
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 905
# =================================================================
# Total params: 47,165
# Trainable params: 47,165
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00034: early stopping
# Test loss: 0.453140210701
# Test accuracy: 0.87991433382
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 190)               48830
# _________________________________________________________________
# dense_41 (Dense)             (None, 5)                 955
# =================================================================
# Total params: 49,785
# Trainable params: 49,785
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00026: early stopping
# Test loss: 0.475243331461
# Test accuracy: 0.871883126835
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 200)               51400
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.465522845914
# Test accuracy: 0.874789658838
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_44 (Dense)             (None, 210)               53970
# _________________________________________________________________
# dense_45 (Dense)             (None, 5)                 1055
# =================================================================
# Total params: 55,025
# Trainable params: 55,025
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00034: early stopping
# Test loss: 0.463444447461
# Test accuracy: 0.88014379684
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 220)               56540
# _________________________________________________________________
# dense_47 (Dense)             (None, 5)                 1105
# =================================================================
# Total params: 57,645
# Trainable params: 57,645
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.462584171941
# Test accuracy: 0.882744378182
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 230)               59110
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 1155
# =================================================================
# Total params: 60,265
# Trainable params: 60,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.45455540592
# Test accuracy: 0.879531895347
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_50 (Dense)             (None, 240)               61680
# _________________________________________________________________
# dense_51 (Dense)             (None, 5)                 1205
# =================================================================
# Total params: 62,885
# Trainable params: 62,885
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.456666760362
# Test accuracy: 0.88144408752
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_52 (Dense)             (None, 250)               64250
# _________________________________________________________________
# dense_53 (Dense)             (None, 5)                 1255
# =================================================================
# Total params: 65,505
# Trainable params: 65,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00034: early stopping
# Test loss: 0.454256744975
# Test accuracy: 0.8815970629
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 260)               66820
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 1305
# =================================================================
# Total params: 68,125
# Trainable params: 68,125
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00026: early stopping
# Test loss: 0.470504009963
# Test accuracy: 0.87456019579
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 270)               69390
# _________________________________________________________________
# dense_57 (Dense)             (None, 5)                 1355
# =================================================================
# Total params: 70,745
# Trainable params: 70,745
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.466078599695
# Test accuracy: 0.875019121949
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_58 (Dense)             (None, 280)               71960
# _________________________________________________________________
# dense_59 (Dense)             (None, 5)                 1405
# =================================================================
# Total params: 73,365
# Trainable params: 73,365
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.455128861936
# Test accuracy: 0.883815205779
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 290)               74530
# _________________________________________________________________
# dense_61 (Dense)             (None, 5)                 1455
# =================================================================
# Total params: 75,985
# Trainable params: 75,985
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.503345601253
# Test accuracy: 0.866070062747
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_62 (Dense)             (None, 300)               77100
# _________________________________________________________________
# dense_63 (Dense)             (None, 5)                 1505
# =================================================================
# Total params: 78,605
# Trainable params: 78,605
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00031: early stopping
# Test loss: 0.451075647427
# Test accuracy: 0.881061649056
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_64 (Dense)             (None, 310)               79670
# _________________________________________________________________
# dense_65 (Dense)             (None, 5)                 1555
# =================================================================
# Total params: 81,225
# Trainable params: 81,225
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.457206178942
# Test accuracy: 0.881520575169
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 320)               82240
# _________________________________________________________________
# dense_67 (Dense)             (None, 5)                 1605
# =================================================================
# Total params: 83,845
# Trainable params: 83,845
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00030: early stopping
# Test loss: 0.474545263603
# Test accuracy: 0.873106929812
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_68 (Dense)             (None, 330)               84810
# _________________________________________________________________
# dense_69 (Dense)             (None, 5)                 1655
# =================================================================
# Total params: 86,465
# Trainable params: 86,465
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00034: early stopping
# Test loss: 0.460795780606
# Test accuracy: 0.881520575215
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_70 (Dense)             (None, 340)               87380
# _________________________________________________________________
# dense_71 (Dense)             (None, 5)                 1705
# =================================================================
# Total params: 89,085
# Trainable params: 89,085
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00023: early stopping
# Test loss: 0.468379365116
# Test accuracy: 0.873259905174
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 350)               89950
# _________________________________________________________________
# dense_73 (Dense)             (None, 5)                 1755
# =================================================================
# Total params: 91,705
# Trainable params: 91,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00038: early stopping
# Test loss: 0.500455393619
# Test accuracy: 0.873412880544
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_74 (Dense)             (None, 360)               92520
# _________________________________________________________________
# dense_75 (Dense)             (None, 5)                 1805
# =================================================================
# Total params: 94,325
# Trainable params: 94,325
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.462263466756
# Test accuracy: 0.881826525911
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 370)               95090
# _________________________________________________________________
# dense_77 (Dense)             (None, 5)                 1855
# =================================================================
# Total params: 96,945
# Trainable params: 96,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.462079229884
# Test accuracy: 0.881903013597
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (None, 380)               97660
# _________________________________________________________________
# dense_79 (Dense)             (None, 5)                 1905
# =================================================================
# Total params: 99,565
# Trainable params: 99,565
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.455950184825
# Test accuracy: 0.879531895383
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_80 (Dense)             (None, 390)               100230
# _________________________________________________________________
# dense_81 (Dense)             (None, 5)                 1955
# =================================================================
# Total params: 102,185
# Trainable params: 102,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00033: early stopping
# Test loss: 0.473869758684
# Test accuracy: 0.878996481548
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_82 (Dense)             (None, 400)               102800
# _________________________________________________________________
# dense_83 (Dense)             (None, 5)                 2005
# =================================================================
# Total params: 104,805
# Trainable params: 104,805
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.460669953501
# Test accuracy: 0.883585742668
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (None, 410)               105370
# _________________________________________________________________
# dense_85 (Dense)             (None, 5)                 2055
# =================================================================
# Total params: 107,425
# Trainable params: 107,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.454565459396
# Test accuracy: 0.879608383069
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_86 (Dense)             (None, 420)               107940
# _________________________________________________________________
# dense_87 (Dense)             (None, 5)                 2105
# =================================================================
# Total params: 110,045
# Trainable params: 110,045
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00033: early stopping
# Test loss: 0.468538513475
# Test accuracy: 0.880832186036
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 430)               110510
# _________________________________________________________________
# dense_89 (Dense)             (None, 5)                 2155
# =================================================================
# Total params: 112,665
# Trainable params: 112,665
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00021: early stopping
# Test loss: 0.484569432877
# Test accuracy: 0.867829279459
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 440)               113080
# _________________________________________________________________
# dense_91 (Dense)             (None, 5)                 2205
# =================================================================
# Total params: 115,285
# Trainable params: 115,285
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.469449691571
# Test accuracy: 0.88488603333
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_92 (Dense)             (None, 450)               115650
# _________________________________________________________________
# dense_93 (Dense)             (None, 5)                 2255
# =================================================================
# Total params: 117,905
# Trainable params: 117,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.45502900971
# Test accuracy: 0.883968181141
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 460)               118220
# _________________________________________________________________
# dense_95 (Dense)             (None, 5)                 2305
# =================================================================
# Total params: 120,525
# Trainable params: 120,525
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00037: early stopping
# Test loss: 0.46936556096
# Test accuracy: 0.88228545207
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 470)               120790
# _________________________________________________________________
# dense_97 (Dense)             (None, 5)                 2355
# =================================================================
# Total params: 123,145
# Trainable params: 123,145
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00031: early stopping
# Test loss: 0.462855791889
# Test accuracy: 0.884121156476
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_98 (Dense)             (None, 480)               123360
# _________________________________________________________________
# dense_99 (Dense)             (None, 5)                 2405
# =================================================================
# Total params: 125,765
# Trainable params: 125,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00041: early stopping
# Test loss: 0.467779095086
# Test accuracy: 0.88702768856
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 490)               125930
# _________________________________________________________________
# dense_101 (Dense)            (None, 5)                 2455
# =================================================================
# Total params: 128,385
# Trainable params: 128,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00037: early stopping
# Test loss: 0.485310707925
# Test accuracy: 0.881979501319
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_102 (Dense)            (None, 500)               128500
# _________________________________________________________________
# dense_103 (Dense)            (None, 5)                 2505
# =================================================================
# Total params: 131,005
# Trainable params: 131,005
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.46101633632
# Test accuracy: 0.879761358403
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_104 (Dense)            (None, 510)               131070
# _________________________________________________________________
# dense_105 (Dense)            (None, 5)                 2555
# =================================================================
# Total params: 133,625
# Trainable params: 133,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.49572428456
# Test accuracy: 0.874636683476
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_106 (Dense)            (None, 520)               133640
# _________________________________________________________________
# dense_107 (Dense)            (None, 5)                 2605
# =================================================================
# Total params: 136,245
# Trainable params: 136,245
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00036: early stopping
# Test loss: 0.482086606149
# Test accuracy: 0.879531895337
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_108 (Dense)            (None, 530)               136210
# _________________________________________________________________
# dense_109 (Dense)            (None, 5)                 2655
# =================================================================
# Total params: 138,865
# Trainable params: 138,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00021: early stopping
# Test loss: 0.473912237534
# Test accuracy: 0.874254245085
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            (None, 540)               138780
# _________________________________________________________________
# dense_111 (Dense)            (None, 5)                 2705
# =================================================================
# Total params: 141,485
# Trainable params: 141,485
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00035: early stopping
# Test loss: 0.469550590254
# Test accuracy: 0.88396818115
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_112 (Dense)            (None, 550)               141350
# _________________________________________________________________
# dense_113 (Dense)            (None, 5)                 2755
# =================================================================
# Total params: 144,105
# Trainable params: 144,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00030: early stopping
# Test loss: 0.4701848535
# Test accuracy: 0.882438427395
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_114 (Dense)            (None, 560)               143920
# _________________________________________________________________
# dense_115 (Dense)            (None, 5)                 2805
# =================================================================
# Total params: 146,725
# Trainable params: 146,725
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.471673478596
# Test accuracy: 0.877390240144
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_116 (Dense)            (None, 570)               146490
# _________________________________________________________________
# dense_117 (Dense)            (None, 5)                 2855
# =================================================================
# Total params: 149,345
# Trainable params: 149,345
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00026: early stopping
# Test loss: 0.472130913399
# Test accuracy: 0.878308092424
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_118 (Dense)            (None, 580)               149060
# _________________________________________________________________
# dense_119 (Dense)            (None, 5)                 2905
# =================================================================
# Total params: 151,965
# Trainable params: 151,965
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.462772887486
# Test accuracy: 0.878919993908
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_120 (Dense)            (None, 590)               151630
# _________________________________________________________________
# dense_121 (Dense)            (None, 5)                 2955
# =================================================================
# Total params: 154,585
# Trainable params: 154,585
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00025: early stopping
# Test loss: 0.464275178098
# Test accuracy: 0.880296772201
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_122 (Dense)            (None, 600)               154200
# _________________________________________________________________
# dense_123 (Dense)            (None, 5)                 3005
# =================================================================
# Total params: 157,205
# Trainable params: 157,205
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00031: early stopping
# Test loss: 0.455173556974
# Test accuracy: 0.885727397862
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_124 (Dense)            (None, 610)               156770
# _________________________________________________________________
# dense_125 (Dense)            (None, 5)                 3055
# =================================================================
# Total params: 159,825
# Trainable params: 159,825
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.457490155616
# Test accuracy: 0.879684870745
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_126 (Dense)            (None, 620)               159340
# _________________________________________________________________
# dense_127 (Dense)            (None, 5)                 3105
# =================================================================
# Total params: 162,445
# Trainable params: 162,445
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.487245374715
# Test accuracy: 0.870735811507
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_128 (Dense)            (None, 630)               161910
# _________________________________________________________________
# dense_129 (Dense)            (None, 5)                 3155
# =================================================================
# Total params: 165,065
# Trainable params: 165,065
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00023: early stopping
# Test loss: 0.459924135931
# Test accuracy: 0.878767018528
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_130 (Dense)            (None, 640)               164480
# _________________________________________________________________
# dense_131 (Dense)            (None, 5)                 3205
# =================================================================
# Total params: 167,685
# Trainable params: 167,685
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.46260326772
# Test accuracy: 0.882208964329
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_132 (Dense)            (None, 650)               167050
# _________________________________________________________________
# dense_133 (Dense)            (None, 5)                 3255
# =================================================================
# Total params: 170,305
# Trainable params: 170,305
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.47865394919
# Test accuracy: 0.877160777133
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_134 (Dense)            (None, 660)               169620
# _________________________________________________________________
# dense_135 (Dense)            (None, 5)                 3305
# =================================================================
# Total params: 172,925
# Trainable params: 172,925
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.467121176322
# Test accuracy: 0.882973841184
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_136 (Dense)            (None, 670)               172190
# _________________________________________________________________
# dense_137 (Dense)            (None, 5)                 3355
# =================================================================
# Total params: 175,545
# Trainable params: 175,545
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00023: early stopping
# Test loss: 0.459279809425
# Test accuracy: 0.880449747563
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_138 (Dense)            (None, 680)               174760
# _________________________________________________________________
# dense_139 (Dense)            (None, 5)                 3405
# =================================================================
# Total params: 178,165
# Trainable params: 178,165
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00021: early stopping
# Test loss: 0.478924866251
# Test accuracy: 0.872418540597
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_140 (Dense)            (None, 690)               177330
# _________________________________________________________________
# dense_141 (Dense)            (None, 5)                 3455
# =================================================================
# Total params: 180,785
# Trainable params: 180,785
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.483310490769
# Test accuracy: 0.873565855906
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_142 (Dense)            (None, 700)               179900
# _________________________________________________________________
# dense_143 (Dense)            (None, 5)                 3505
# =================================================================
# Total params: 183,405
# Trainable params: 183,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00018: early stopping
# Test loss: 0.480903043857
# Test accuracy: 0.869588496234
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_157 (Dense)            (None, 5)                 3855
# =================================================================
# Total params: 201,745
# Trainable params: 201,745
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.464050951041
# Test accuracy: 0.88320330425
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_158 (Dense)            (None, 780)               200460
# _________________________________________________________________
# dense_159 (Dense)            (None, 5)                 3905
# =================================================================
# Total params: 204,365
# Trainable params: 204,365
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00025: early stopping
# Test loss: 0.466891880792
# Test accuracy: 0.879837846089
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_160 (Dense)            (None, 790)               203030
# _________________________________________________________________
# dense_161 (Dense)            (None, 5)                 3955
# =================================================================
# Total params: 206,985
# Trainable params: 206,985
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00026: early stopping
# Test loss: 0.456225208009
# Test accuracy: 0.88450359493
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_162 (Dense)            (None, 800)               205600
# _________________________________________________________________
# dense_163 (Dense)            (None, 5)                 4005
# =================================================================
# Total params: 209,605
# Trainable params: 209,605
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00033: early stopping
# Test loss: 0.461719445598
# Test accuracy: 0.89016368362
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_164 (Dense)            (None, 810)               208170
# _________________________________________________________________
# dense_165 (Dense)            (None, 5)                 4055
# =================================================================
# Total params: 212,225
# Trainable params: 212,225
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.456074202213
# Test accuracy: 0.883126816564
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_166 (Dense)            (None, 820)               210740
# _________________________________________________________________
# dense_167 (Dense)            (None, 5)                 4105
# =================================================================
# Total params: 214,845
# Trainable params: 214,845
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.474567215952
# Test accuracy: 0.878537555435
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_168 (Dense)            (None, 830)               213310
# _________________________________________________________________
# dense_169 (Dense)            (None, 5)                 4155
# =================================================================
# Total params: 217,465
# Trainable params: 217,465
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00031: early stopping
# Test loss: 0.473897390807
# Test accuracy: 0.882591402802
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_170 (Dense)            (None, 840)               215880
# _________________________________________________________________
# dense_171 (Dense)            (None, 5)                 4205
# =================================================================
# Total params: 220,085
# Trainable params: 220,085
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00019: early stopping
# Test loss: 0.48069543012
# Test accuracy: 0.873106929757
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_172 (Dense)            (None, 850)               218450
# _________________________________________________________________
# dense_173 (Dense)            (None, 5)                 4255
# =================================================================
# Total params: 222,705
# Trainable params: 222,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.459197818412
# Test accuracy: 0.883126816601
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_174 (Dense)            (None, 860)               221020
# _________________________________________________________________
# dense_175 (Dense)            (None, 5)                 4305
# =================================================================
# Total params: 225,325
# Trainable params: 225,325
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.469970708445
# Test accuracy: 0.881597062855
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_176 (Dense)            (None, 870)               223590
# _________________________________________________________________
# dense_177 (Dense)            (None, 5)                 4355
# =================================================================
# Total params: 227,945
# Trainable params: 227,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.476462866893
# Test accuracy: 0.87287746671
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_178 (Dense)            (None, 880)               226160
# _________________________________________________________________
# dense_179 (Dense)            (None, 5)                 4405
# =================================================================
# Total params: 230,565
# Trainable params: 230,565
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00022: early stopping
# Test loss: 0.473150554939
# Test accuracy: 0.872953954422
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_180 (Dense)            (None, 890)               228730
# _________________________________________________________________
# dense_181 (Dense)            (None, 5)                 4455
# =================================================================
# Total params: 233,185
# Trainable params: 233,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00027: early stopping
# Test loss: 0.460908770032
# Test accuracy: 0.882361939746
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_182 (Dense)            (None, 900)               231300
# _________________________________________________________________
# dense_183 (Dense)            (None, 5)                 4505
# =================================================================
# Total params: 235,805
# Trainable params: 235,805
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00026: early stopping
# Test loss: 0.480870430657
# Test accuracy: 0.874101269677
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_184 (Dense)            (None, 910)               233870
# _________________________________________________________________
# dense_185 (Dense)            (None, 5)                 4555
# =================================================================
# Total params: 238,425
# Trainable params: 238,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00022: early stopping
# Test loss: 0.459434899648
# Test accuracy: 0.881061649047
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_186 (Dense)            (None, 920)               236440
# _________________________________________________________________
# dense_187 (Dense)            (None, 5)                 4605
# =================================================================
# Total params: 241,045
# Trainable params: 241,045
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00022: early stopping
# Test loss: 0.471819323412
# Test accuracy: 0.877313752468
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_188 (Dense)            (None, 930)               239010
# _________________________________________________________________
# dense_189 (Dense)            (None, 5)                 4655
# =================================================================
# Total params: 243,665
# Trainable params: 243,665
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.494302351257
# Test accuracy: 0.871959614493
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_190 (Dense)            (None, 940)               241580
# _________________________________________________________________
# dense_191 (Dense)            (None, 5)                 4705
# =================================================================
# Total params: 246,285
# Trainable params: 246,285
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.492693914456
# Test accuracy: 0.877160777097
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_192 (Dense)            (None, 950)               244150
# _________________________________________________________________
# dense_193 (Dense)            (None, 5)                 4755
# =================================================================
# Total params: 248,905
# Trainable params: 248,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00025: early stopping
# Test loss: 0.475455478342
# Test accuracy: 0.881061649084
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_194 (Dense)            (None, 960)               246720
# _________________________________________________________________
# dense_195 (Dense)            (None, 5)                 4805
# =================================================================
# Total params: 251,525
# Trainable params: 251,525
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00022: early stopping
# Test loss: 0.461487562317
# Test accuracy: 0.880067309136
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_196 (Dense)            (None, 970)               249290
# _________________________________________________________________
# dense_197 (Dense)            (None, 5)                 4855
# =================================================================
# Total params: 254,145
# Trainable params: 254,145
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.4879305851
# Test accuracy: 0.880679210665
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_198 (Dense)            (None, 980)               251860
# _________________________________________________________________
# dense_199 (Dense)            (None, 5)                 4905
# =================================================================
# Total params: 256,765
# Trainable params: 256,765
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00031: early stopping
# Test loss: 0.478221731028
# Test accuracy: 0.882285452024
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_200 (Dense)            (None, 990)               254430
# _________________________________________________________________
# dense_201 (Dense)            (None, 5)                 4955
# =================================================================
# Total params: 259,385
# Trainable params: 259,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00024: early stopping
# Test loss: 0.508267746864
# Test accuracy: 0.866681964176
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_202 (Dense)            (None, 1000)              257000
# _________________________________________________________________
# dense_203 (Dense)            (None, 5)                 5005
# =================================================================
# Total params: 262,005
# Trainable params: 262,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
#read JSON file
with open('SavedData/ex4_results_every10.txt') as json_data:
    history_ex4 = json.load(json_data)

# %%
final_loss = []
final_acc = []

#keep all final accuracies and loss in lists
for i in range(10,1001,10):
    final_loss.append(history_ex4[str(i)]['val_loss'][-1])
    final_acc.append(history_ex4[str(i)]['val_acc'][-1])
    
#plot
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(range(10,1001,10),final_loss, label='Final categorical cross entropies');
ax1.set_ylabel('categorical cross entropy')
ax1.set_xlabel('Number of Hidden Neurons (10-1000)')
ax1.set_title('Final Categorical Cross Entropies');
ax2.plot(range(10,1001,10),final_acc, label='Final accuracies [% correct]');
ax2.set_ylabel('accuracy [% correct]')
ax2.set_xlabel('Number of Hidden Neurons (10-1000)')
ax2.set_title('Final Accuracies');
fig.tight_layout()

# %% [markdown]
# Now, fit models for 50, 100, 150 and 200 hidden neurons multiple times:

# %%
#THIS BLOCK TAKES A FEW HOURS TO RUN
history_list4_2 = {}
howmany = 20
N_H = [50,100,150,200]

for i in N_H:
    history_list4_2[i] = []
    #run 'howmany' times each model
    for j in range(0,howmany):
        history_tmp = adam_optimizer(N_hidden=i, K_hidden=1, ES_bool=True, epochs=1000, verbose=0)
        history_list4_2[i].append(history_tmp.history)
        
#save statistics in json
with open('SavedData/ex4_2_results.txt', 'w') as outfile:
    json.dump(history_list4_2, outfile)
# Out:
# Epoch 00072: early stopping
# Test loss: 0.481790328944
# Test accuracy: 0.875095609589
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_204 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_205 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00051: early stopping
# Test loss: 0.509063739117
# Test accuracy: 0.862781092262
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_206 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_207 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00052: early stopping
# Test loss: 0.535364156818
# Test accuracy: 0.856356126682
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_208 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_209 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00033: early stopping
# Test loss: 0.582848752623
# Test accuracy: 0.836239865373
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_210 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_211 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00049: early stopping
# Test loss: 0.532659164669
# Test accuracy: 0.85490286063
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_212 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_213 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00044: early stopping
# Test loss: 0.511177827253
# Test accuracy: 0.862475141484
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_214 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_215 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00052: early stopping
# Test loss: 0.521281216019
# Test accuracy: 0.859645097158
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_216 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_217 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00057: early stopping
# Test loss: 0.505126471911
# Test accuracy: 0.865917087367
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_218 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_219 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00049: early stopping
# Test loss: 0.508558483577
# Test accuracy: 0.86484625978
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_220 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_221 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00067: early stopping
# Test loss: 0.515729156577
# Test accuracy: 0.866070062738
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_222 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_223 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00039: early stopping
# Test loss: 0.519427338493
# Test accuracy: 0.853755545385
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_224 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_225 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00052: early stopping
# Test loss: 0.519191658376
# Test accuracy: 0.862322166113
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_226 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_227 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00075: early stopping
# Test loss: 0.478189700848
# Test accuracy: 0.876395900242
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_228 (Dense)            (None, 50)                12850
# _________________________________________________________________
# dense_229 (Dense)            (None, 5)                 255
# =================================================================
# Total params: 13,105
# Trainable params: 13,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00044: early stopping
# Test loss: 0.537843251677
# Test accuracy: 0.852914180808
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense
(Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00032: early stopping
# Test loss: 0.466697139506
# Test accuracy: 0.876472387973
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_354 (Dense)            (None, 200)               51400
# _________________________________________________________________
# dense_355 (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00040: early stopping
# Test loss: 0.468810974726
# Test accuracy: 0.878843506214
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_356 (Dense)            (None, 200)               51400
# _________________________________________________________________
# dense_357 (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00030: early stopping
# Test loss: 0.496515816763
# Test accuracy: 0.86576411196
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_358 (Dense)            (None, 200)               51400
# _________________________________________________________________
# dense_359 (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00028: early stopping
# Test loss: 0.479186504642
# Test accuracy: 0.86897659475
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_360 (Dense)            (None, 200)               51400
# _________________________________________________________________
# dense_361 (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00029: early stopping
# Test loss: 0.473994843453
# Test accuracy: 0.871424200685
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_362 (Dense)            (None, 200)               51400
# _________________________________________________________________
# dense_363 (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 52,405
# Trainable params: 52,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
#read JSON file
with open('SavedData/ex4_results_20times.txt') as json_data:
    history_ex4_2 = json.load(json_data)

# %%
final_loss = []
final_acc = []

#keep all final accuracies and loss in lists
for k in N_H:
    loss_tmp = []
    acc_tmp = []
    for i in range(0,howmany):
        loss_tmp.append(history_ex4_2[str(k)][i]['val_loss'][-1])
        acc_tmp.append(history_ex4_2[str(k)][i]['val_acc'][-1])
    final_loss.append(loss_tmp)
    final_acc.append(acc_tmp)

#boxplot
fig, (ax1, ax2) = plt.subplots(1, 2)
labels = ['50 Hidden Neurons', '100 Hidden Neurons', '150 Hidden Neurons', '200 Hidden Neurons',]
ax1.boxplot(final_loss,labels=labels);
ax1.set_ylabel('Final categorical cross entropies')
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=20)
ax2.boxplot(final_acc,labels=labels);
ax2.set_ylabel('Final accuracies [% correct]')
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=20)
fig.suptitle('Final Validation Results ({} runs each)'.format(str(howmany)));
fig.tight_layout()
plt.subplots_adjust(top=0.9)

# %% [markdown]
# ## Exercise 5: Comparison to deep models
#
# ### Description
#
# Instead of choosing one hidden layer (with many neurons) you experiment here with multiple hidden layers (each with not so many neurons).
#
# 1. Fit models with 2, 3 and 4 hidden layers with approximately the same number of parameters as a network with one hidden layer of 100 neurons. Hint: Calculate the number of parameters in a network with input dimensionality N_in, K hidden layers with N_h units, one output layer with N_out dimensions and solve for N_h. Confirm you result with the keras method model.summary().
# 2. Run each model multiple times with different initial conditions and plot summary statistics of the best validation loss and accuracy versus the number of hidden layers.
#
# ### Solution

# %% [markdown]
# The number of parameters in a Deep Neural Network is:
#
# $$ Nb_{parameters} = N_h \cdot [N_{in} + N_{out} + (N_h+1)\cdot(K-1)] + N_{out} $$
#
# To find $ N_h $ to have always the same number of parameters as a network with one hidden layer of 100 neurons, one must solve:
#
# $$ N_h²\cdot(K-1) + N_h\cdot(N_{in}+N_{out}+K-1)-100\cdot(N_{in}+N_{out}) = 0$$

# %%
#THIS BLOCK TAKES A FEW HOURS TO RUN
K = [2, 3, 4]
N_in = x_train.shape[1] +1  #256 + threshold
N_out = len(subset_of_classes) #5
history_list5 = {}

howmany = 20
            
#Equation to solve to find N_h
def f(x):
    return (x**2 *(k-1) + x *(N_in+N_out+k-1) - 100*(N_in+N_out))

for k in K:
    history_list5[k] = []
    #find N_h
    N_h = int(round(fsolve(f,0)[0]))
    #run 'howmany' times each model
    for i in range (0,howmany):        
        tmp_history = adam_optimizer(N_hidden=N_h, K_hidden=k, ES_bool=True, epochs=1000, verbose=0, SUMMARY=True)
        history_list5[k].append(tmp_history.history)
        
#save statistics in json
with open('SavedData/ex5_results.txt', 'w') as outfile:
    json.dump(history_list5, outfile)
# Out:
# Epoch 00040: early stopping
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense
(Dense)            (None, 59)                3540
# _________________________________________________________________
# dense_914 (Dense)            (None, 59)                3540
# _________________________________________________________________
# dense_915 (Dense)            (None, 5)                 300
# =================================================================
# Total params: 26,083
# Trainable params: 26,083
# Non-trainable params: 0
# _________________________________________________________________

# %%
#read JSON file
with open('SavedData/ex5_results.txt') as json_data:
    history_ex5 = json.load(json_data)

# %% [markdown]
# Comapre Curves of best accuracy and best cross entropy:

# %%
best_loss = {}
best_acc = {}

#find best accuracy results
for k in K:
    best_loss[k] = history_ex5[str(k)][0]['val_loss']
    best_acc[k] = history_ex5[str(k)][0]['val_acc']
    for i in range(0,howmany):
        loss = history_ex5[str(k)][i]['val_loss']
        acc = history_ex5[str(k)][i]['val_acc']        
        best_loss[k] = loss if loss[-1] < best_loss[k][-1] else best_loss[k]
        best_acc[k] = acc if acc[-1] > best_acc[k][-1] else best_acc[k]
                
#plot
fig, ax1, ax2 = prepare_standardplot(' Validation results, bests of {} runs'.format(str(howmany)), 'epoch')
for k in K:
    ax1.plot(best_loss[k], label = str(k)+" Hidden Layers")
    ax2.plot(best_acc[k], label = str(k)+" Hidden Layers")
finalize_standardplot(fig, ax1, ax2)

# %% [markdown]
# Make Boxplots of best results accross all models:

# %%
best_loss = []
best_acc = []

#keep all best accuracies and loss in lists
for k in K:
    loss_tmp = []
    acc_tmp = []
    for i in range(0,howmany):
        loss_tmp.append(history_ex5[str(k)][i]['val_loss'][-1])
        acc_tmp.append(history_ex5[str(k)][i]['val_acc'][-1])
    best_loss.append(loss_tmp)
    best_acc.append(acc_tmp)

#boxplot
fig, (ax1, ax2) = plt.subplots(1, 2)
labels = ['2 Hidden Layers', '3 Hidden Layers', '4 Hidden Layers']
ax1.boxplot(best_loss,labels=labels);
ax1.set_ylabel('Final categorical cross entropies')
ax2.boxplot(best_acc,labels=labels);
ax2.set_ylabel('Final accuracies [% correct]')
fig.suptitle('Final Validation Results ({} runs each)'.format(str(howmany)));
fig.tight_layout()
plt.subplots_adjust(top=0.9)

# %% [markdown]
# ## Exercise 6: Tricks (regularization, batch normalization, dropout)
#
# ### Description
#
# Overfitting can also be counteracted with regularization and dropout. Batch normalization is supposed to mainly decrease convergence time.
#
# 1. Try to improve the best validation scores of the model with 1 layer and 100 hidden neurons and the model with 4 hidden layers. Experiment with batch_normalization layers, dropout layers and l1- and l2-regularization on weights (kernels) and biases.
# 2. After you have found good settings, plot for both models the learning curves of the naive model you fitted in the previous exercises together with the learning curves of the current version.
# 3. For proper comparison, plot also the learning curves of the two current models in a third figure.
#
# ### Solution

# %% [markdown]
# Try Batch Normalization Layers:

# %% [markdown]
# Try Dropout Layers:

# %% [markdown]
# Try L1 Normalization:

# %% [markdown]
# Try L2 Normalization:

# %% [markdown]
# Plot new best model VS naive model:

# %% [markdown]
# Plot current model:

# %% [markdown]
# ## Exercise 7: Convolutional networks
#
# ### Description
#
# Convolutional neural networks have an inductive bias that is well adapted to image classification.
#
# 1. Design a convolutional neural network, play with the parameters and fit it. Hint: You may get valuable inspiration from the keras [examples](https://github.com/keras-team/keras/tree/master/examples), e.g. [mnist_cnn](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py).
# 2. Plot the learning curves of the convolutional neural network together with the so far best performing model.
#
# ## Solution
